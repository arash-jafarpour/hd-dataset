# %%
from datetime import datetime
import time,pytz
import os, glob, subprocess, sys, uuid
from tqdm import tqdm

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "1"
import tensorflow as tf

config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.9
config.gpu_options.allow_growth = True
session = tf.compat.v1.InteractiveSession(config=config)

import keras

import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

GLOBAL_RANDOM_SEED = 42

random.seed(GLOBAL_RANDOM_SEED)
np.random.seed(GLOBAL_RANDOM_SEED)
tf.random.set_seed(GLOBAL_RANDOM_SEED)
tf.config.experimental.enable_op_determinism()
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
initializer = keras.initializers.GlorotUniform(seed=GLOBAL_RANDOM_SEED)
# Out:
# 2025-09-16 13:18:57.706453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758016137.791328   77849 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758016137.816198   77849 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-16 13:19:05.554950: E tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:55] The TF_FORCE_GPU_ALLOW_GROWTH environment variable is set but could not be parsed: "1". Valid values are "true" or "false". Using original config value of 1.
# I0000 00:00:1758016145.556017   77849 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5223 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# ========== LOAD & CLEAN ==========
column_names = [
    "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
    "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"
]

files = [
    ("data/processed.cleveland.data", "cleveland"),
    ("data/processed.hungarian.data", "hungarian"),
    ("data/processed.switzerland.data", "switzerland"),
    ("data/processed.va.data", "va")
]

# Load data with source tracking
dfs = []
for file_path, source in files:
    temp_df = pd.read_csv(file_path, names=column_names, na_values='?', header=None)
    temp_df['source'] = source
    dfs.append(temp_df)

df = pd.concat(dfs, ignore_index=True)

# Convert columns to numeric, binarize target
for col in column_names:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df['target'] = df['target'].apply(lambda x: 1 if x > 0 else 0)

print(df.describe())
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  920.000000  920.000000  920.000000  861.000000  890.000000  830.000000
# mean    53.510870    0.789130    3.250000  132.132404  199.130337    0.166265
# std      9.424685    0.408148    0.930969   19.066070  110.780810    0.372543
# min     28.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     47.000000    1.000000    3.000000  120.000000  175.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  223.000000    0.000000
# 75%     60.000000    1.000000    4.000000  140.000000  268.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  918.000000  865.000000  865.000000  858.000000  611.000000  309.000000
# mean     0.604575  137.545665    0.389595    0.878788    1.770867    0.676375
# std      0.805827   25.926276    0.487941    1.091226    0.619256    0.935653
# min      0.000000   60.000000    0.000000   -2.600000    1.000000    0.000000
# 25%      0.000000  120.000000    0.000000    0.000000    1.000000    0.000000
# 50%      0.000000  140.000000    0.000000    0.500000    2.000000    0.000000
# 75%      1.000000  157.000000    1.000000    1.500000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal      target
# count  434.000000  920.000000
# mean     5.087558    0.553261
# std      1.919075    0.497426
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      6.000000    1.000000
# 75%      7.000000    1.000000
# max      7.000000    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='target', data=df)
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
# from sklearn.base import BaseEstimator, ClassifierMixin, clone
# from sklearn.model_selection import cross_val_predict, StratifiedKFold
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import StackingClassifier
# from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# import numpy as np

# # -------- TieredStackingClassifier --------
# class TieredStackingClassifier(BaseEstimator, ClassifierMixin):
#     def __init__(self, groups, meta_estimators=None, final_estimator=None, cv=5, random_state=None):
#         self.groups = groups
#         self.meta_estimators = meta_estimators or {}
#         self.final_estimator = final_estimator or LogisticRegression(max_iter=1000)
#         self.cv = cv
#         self.random_state = random_state
#         self._group_models = {}

#     def _make_group_stack(self, estimators, meta_estimator):
#         return StackingClassifier(
#             estimators=estimators,
#             final_estimator=clone(meta_estimator),
#             cv=self.cv,
#             passthrough=False,
#             n_jobs=-1
#         )

#     def fit(self, X, y):
#         skf = StratifiedKFold(n_splits=self.cv, shuffle=True, random_state=self.random_state)
#         group_oof = []
#         group_names = []
#         for gname, estimators in self.groups.items():
#             meta = self.meta_estimators.get(gname, LogisticRegression(max_iter=1000))
#             stack_clf = self._make_group_stack(estimators, meta)
#             # produce true out-of-fold probabilities for the positive class
#             oof = cross_val_predict(clone(stack_clf), X, y, cv=skf, method='predict_proba', n_jobs=-1)
#             if oof.ndim == 2:
#                 oof_pos = oof[:, 1].reshape(-1, 1)
#             else:
#                 oof_pos = oof.reshape(-1, 1)
#             group_oof.append(oof_pos)
#             group_names.append(gname)
#             # fit on full data for inference
#             fitted = clone(stack_clf).fit(X, y)
#             self._group_models[gname] = fitted

#         final_X = np.hstack(group_oof)
#         self._final_features_ = group_names
#         self.final_estimator_ = clone(self.final_estimator).fit(final_X, y)
#         return self

#     def predict_proba(self, X):
#         proba_cols = []
#         for gname in self._final_features_:
#             model = self._group_models[gname]
#             p = model.predict_proba(X)[:, 1].reshape(-1, 1)
#             proba_cols.append(p)
#         meta_X = np.hstack(proba_cols)
#         return self.final_estimator_.predict_proba(meta_X)

#     def predict(self, X):
#         proba = self.predict_proba(X)[:, 1]
#         return (proba >= 0.5).astype(int)


# # -------- CV-weighted voting builder (selector-aware) --------
# def build_cv_weighted_voting_for_selector(base_learners, selector_steps, X, y, cv=3, scoring='roc_auc'):
#     """
#     base_learners: list of (name, estimator) - raw estimators, not pipelines
#     selector_steps: list of transformer tuples (same as your sel_steps)
#     X,y: training data (full)
#     Returns: VotingClassifier with weights computed on selector-aware pipelines
#     """
#     from sklearn.pipeline import Pipeline as SklearnPipeline
#     from imblearn.pipeline import Pipeline as ImbPipelineLocal
#     from sklearn.model_selection import cross_val_score
#     from imblearn.over_sampling import SMOTE
#     from sklearn.preprocessing import StandardScaler
#     import numpy as np
#     scores = []
#     for name, est in base_learners:
#         # pipeline that mirrors what you'll run during training: scaler + selector + smote + estimator
#         pipe = ImbPipelineLocal([("scaler", StandardScaler())] + selector_steps + [("smote", SMOTE(random_state=GLOBAL_RANDOM_SEED)), ("model", clone(est))])
#         s = cross_val_score(pipe, X, y, cv=cv, scoring=scoring, n_jobs=-1)
#         mean_score = np.mean(s)
#         scores.append(mean_score)
#         print(f"[CV weight] {name}: mean {scoring} = {mean_score:.4f}")
#     scores = np.array(scores)
#     if scores.sum() == 0:
#         weights = [1.0] * len(scores)
#     else:
#         weights = (scores / scores.sum()).tolist()
#     from sklearn.ensemble import VotingClassifier
#     voting = VotingClassifier(estimators=base_learners, voting='soft', weights=weights, n_jobs=-1)
#     return voting, weights


# # -------- Hybrid stacking builder (RF + XGB) --------
# def build_hybrid_stacking(random_state=None):
#     hybrid_estimators = [
#         ('rf', RandomForestClassifier(n_estimators=200, random_state=random_state)),
#         ('xgb', XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=random_state))
#     ]
#     final_meta = LogisticRegression(max_iter=1000)
#     stacking = StackingClassifier(estimators=hybrid_estimators, final_estimator=final_meta, passthrough=True, cv=5, n_jobs=-1)
#     return stacking

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from skrebate import ReliefF
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from scipy.stats import randint, uniform
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.base import BaseEstimator, ClassifierMixin
import numpy as np
import pandas as pd

# FIX: Refactor AdvancedStackingEstimator to be a proper scikit-learn estimator
class AdvancedStackingEstimator(BaseEstimator, ClassifierMixin):
    def __init__(self, base_learners=None, meta_learner=None, selector_steps=None, n_folds=5, random_state=42):
        self.base_learners = base_learners
        self.meta_learner = meta_learner
        self.selector_steps = selector_steps if selector_steps else []
        self.n_folds = n_folds
        self.random_state = random_state
        self.trained_base_learners = []
        self.trained_meta_learner = None
        self.preprocessor = None
        self.oof_results = {}
        self.oof_y_true = None
        self.best_threshold = 0.5
        
    def fit(self, X, y):
        self.oof_y_true = y
        self.preprocessor = ImbPipeline([("scaler", StandardScaler())] + self.selector_steps)
        X_processed = self.preprocessor.fit_transform(X, y)
        
        skf = StratifiedKFold(n_splits=self.n_folds, shuffle=True, random_state=self.random_state)
        meta_features_train = np.zeros((X.shape[0], len(self.base_learners)))
        self.trained_base_learners = []
        self.oof_results = {}
        
        for i, (name, model) in enumerate(self.base_learners):
            fold_preds = np.zeros(X.shape[0])
            trained_model_list = []
            
            for fold_idx, (train_idx, valid_idx) in enumerate(skf.split(X_processed, y)):
                X_tr, X_val = X_processed[train_idx], X_processed[valid_idx]
                y_tr, y_val = y[train_idx], y[valid_idx]
                
                smote = SMOTE(random_state=self.random_state)
                X_tr_resampled, y_tr_resampled = smote.fit_resample(X_tr, y_tr)
                
                model.fit(X_tr_resampled, y_tr_resampled)
                fold_preds[valid_idx] = model.predict_proba(X_val)[:, 1]
                trained_model_list.append(model)
                
            meta_features_train[:, i] = fold_preds
            self.trained_base_learners.append(trained_model_list)
            self.oof_results[name] = fold_preds
            
        # Tune the meta-learner on the OOF predictions
        meta_param_grid = {"C": uniform(0.1, 10), "penalty": ['l2', 'l1'], "solver": ['liblinear']}
        meta_search = RandomizedSearchCV(self.meta_learner, meta_param_grid, cv=3, scoring='roc_auc', n_iter=20, n_jobs=-1, random_state=self.random_state)
        meta_search.fit(meta_features_train, y)
        self.trained_meta_learner = meta_search.best_estimator_

        # Find optimal threshold on OOF predictions
        oof_meta_probs = self.trained_meta_learner.predict_proba(meta_features_train)[:, 1]
        self.best_threshold = self.find_optimal_threshold(self.oof_y_true, oof_meta_probs)
        
        return self

    def predict(self, X):
        X_processed = self.preprocessor.transform(X)
        meta_features_test = np.zeros((X.shape[0], len(self.base_learners)))
        
        for i, _ in enumerate(self.base_learners):
            test_probs = np.zeros((X.shape[0], self.n_folds))
            for fold_idx, model in enumerate(self.trained_base_learners[i]):
                test_probs[:, fold_idx] = model.predict_proba(X_processed)[:, 1]
            meta_features_test[:, i] = test_probs.mean(axis=1)
            
        final_probs = self.trained_meta_learner.predict_proba(meta_features_test)[:, 1]
        
        # Apply the optimized threshold
        final_preds = (final_probs > self.best_threshold).astype(int)
        return final_preds
    
    def predict_proba(self, X):
        X_processed = self.preprocessor.transform(X)
        meta_features_test = np.zeros((X.shape[0], len(self.base_learners)))
        
        for i, _ in enumerate(self.base_learners):
            test_probs = np.zeros((X.shape[0], self.n_folds))
            for fold_idx, model in enumerate(self.trained_base_learners[i]):
                test_probs[:, fold_idx] = model.predict_proba(X_processed)[:, 1]
            meta_features_test[:, i] = test_probs.mean(axis=1)
            
        return self.trained_meta_learner.predict_proba(meta_features_test)

    def find_optimal_threshold(self, y_true, y_probs):
        thresholds = np.linspace(0.0, 1.0, 100)
        f1_scores = [f1_score(y_true, (y_probs >= t).astype(int)) for t in thresholds]
        best_threshold = thresholds[np.argmax(f1_scores)]
        return best_threshold

# class AdvancedStackingEstimator(BaseEstimator, ClassifierMixin):
#     def __init__(self, base_learners=None, meta_learner=None, selector_steps=None):
#         self.base_learners = base_learners
#         self.meta_learner = meta_learner
#         self.selector_steps = selector_steps if selector_steps else []
        
#     def fit(self, X, y):
#         self.X_train_ = X
#         self.y_train_ = y
#         return self
        
#     def predict(self, X):
#         preds, _, _ = cross_validated_stacking(
#             self.base_learners, self.meta_learner, 
#             self.X_train_, self.y_train_, X, self.selector_steps
#         )
#         return preds
        
#     def predict_proba(self, X):
#         _, probs, _ = cross_validated_stacking(
#             self.base_learners, self.meta_learner, 
#             self.X_train_, self.y_train_, X, self.selector_steps
#         )
#         return np.vstack([1-probs, probs]).T

def cross_validated_stacking(base_learners, meta_learner, X_train, y_train, X_test, selector_steps, n_folds=5):
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=GLOBAL_RANDOM_SEED)
    meta_features_train = np.zeros((X_train.shape[0], len(base_learners)))
    meta_features_test = np.zeros((X_test.shape[0], len(base_learners)))
    oof_results = {}
    
    for i, (name, model) in enumerate(base_learners):
        fold_preds = np.zeros(X_train.shape[0])
        test_preds = np.zeros((X_test.shape[0], n_folds))
        
        for fold_idx, (train_idx, valid_idx) in enumerate(skf.split(X_train, y_train)):
            X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[valid_idx]
            y_tr, y_val = y_train[train_idx], y_train[valid_idx]
            
            # Create and fit preprocessor for this fold
            preprocessor_steps = [("scaler", StandardScaler())] + selector_steps
            preprocessor = ImbPipeline(preprocessor_steps)
            X_tr_processed = preprocessor.fit_transform(X_tr, y_tr)
            X_val_processed = preprocessor.transform(X_val)
            X_test_processed = preprocessor.transform(X_test)
            
            # Apply SMOTE
            smote = SMOTE(random_state=GLOBAL_RANDOM_SEED)
            X_tr_resampled, y_tr_resampled = smote.fit_resample(X_tr_processed, y_tr)
            
            # Train model and make predictions
            model.fit(X_tr_resampled, y_tr_resampled)
            fold_preds[valid_idx] = model.predict_proba(X_val_processed)[:, 1]
            test_preds[:, fold_idx] = model.predict_proba(X_test_processed)[:, 1]
        
        meta_features_train[:, i] = fold_preds
        meta_features_test[:, i] = test_preds.mean(axis=1)
        oof_results[name] = fold_preds
    
    # Train meta-learner
    meta_learner.fit(meta_features_train, y_train)
    final_preds = meta_learner.predict(meta_features_test)
    final_probs = meta_learner.predict_proba(meta_features_test)[:, 1]
    
    return final_preds, final_probs, oof_results

# ======== IMPUTATION ========
dfs_imputed = []
for source in df['source'].unique():
    temp = df[df['source'] == source].copy()
    numeric_cols = temp.select_dtypes(include=[np.number]).columns.drop('target')
    imputer = KNNImputer(n_neighbors=min(5, len(temp)-1))
    temp[numeric_cols] = imputer.fit_transform(temp[numeric_cols])
    dfs_imputed.append(temp)

df = pd.concat(dfs_imputed, ignore_index=True)
df = pd.get_dummies(df, columns=['source'], prefix='src')
df = df.fillna(df.median())

# ======== SPLIT ========
X = df.drop('target', axis=1)
y = df['target'].values
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=GLOBAL_RANDOM_SEED
)

# ======== BASE LEARNERS & ENSEMBLES ========
base_learners = [
    ('lr', LogisticRegression(max_iter=1000)),
    ('dt', DecisionTreeClassifier()),
    ('rf', RandomForestClassifier()),
    ('svm', SVC(probability=True)),
    ('knn', KNeighborsClassifier()),
    ('xgb', XGBClassifier(eval_metric='logloss'))
]

voting_clf = VotingClassifier(estimators=base_learners, voting='soft', n_jobs=-1)
stacking_clf = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression(),
                                  passthrough=True, cv=5, n_jobs=-1)

# ======== MODELS & SELECTORS ========
models = {
    "LogReg": LogisticRegression(max_iter=1000),
    "DecTree": DecisionTreeClassifier(),
    "RandForest": RandomForestClassifier(),
    "SVM": SVC(probability=True),
    "KNN": KNeighborsClassifier(),
    "XGBoost": XGBClassifier(eval_metric='logloss'),
    "Voting": voting_clf,
    "Stacking": stacking_clf,
}

selectors = {
    "None": [],
    "Chi2": [("nonneg_shift", FunctionTransformer(lambda x: x - x.min(axis=0))),
             ("select", SelectKBest(chi2, k=10))],
    "MutInfo": [("select", SelectKBest(mutual_info_classif, k=9))],
    "ReliefF": [("select", ReliefF(n_features_to_select=9))],
    "PCA": [("reduce", PCA(n_components=10))]
}

# ======== HYPERPARAMETER GRIDS ========
param_grids = {
    "LogReg": {"model__C": uniform(0.1, 10), "model__penalty": ['l2', None],
               "model__solver": ['newton-cg', 'lbfgs', 'sag']},
    "DecTree": {"model__max_depth": [None, 5, 10, 15, 20, 25], "model__min_samples_split": randint(2, 20),
                "model__min_samples_leaf": randint(1, 10), "model__max_features": ['sqrt', 'log2', None]},
    "RandForest": {"model__n_estimators": [100, 200, 300], "model__max_depth": [None, 10, 20, 30],
                   "model__min_samples_split": [2, 5, 10], "model__min_samples_leaf": [1, 2, 4],
                   "model__max_features": ['sqrt', 'log2']},
    "SVM": {"model__C": uniform(0.1, 10), "model__kernel": ['linear', 'rbf', 'poly'], "model__gamma": ['scale']},
    "KNN": {"model__n_neighbors": randint(3, 15), "model__weights": ['uniform', 'distance'], "model__p": [1, 2]},
    "XGBoost": {"model__n_estimators": [100, 200, 300], "model__max_depth": [3, 6, 9],
                "model__learning_rate": [0.01, 0.05, 0.1], "model__subsample": [0.8, 0.9, 1.0],
                "model__colsample_bytree": [0.8, 0.9, 1.0]},
    "Voting": {"model__weights": [[1, 1, 1, 1, 1, 1], [1, 1, 2, 1, 1, 2], [1, 1, 3, 1, 1, 3]]}
}

# ======== FEATURE EXTRACTION ========
def get_selected_features(pipe, X_train):
    try:
        if "select" in pipe.named_steps:
            sel = pipe.named_steps["select"]
            if hasattr(sel, "get_support"):
                return X_train.columns[sel.get_support()].tolist()
            if hasattr(sel, "top_features_"):
                return [X_train.columns[i] for i in sel.top_features_]
        if "reduce" in pipe.named_steps:
            pc = pipe.named_steps["reduce"]
            n = getattr(pc, "n_components_", getattr(pc, "n_components", None))
            if n: return [f"PC{i+1}" for i in range(n)]
    except Exception as e:
        return [f"[Error: {e}]"]
    return ["[No selector]"]

# ======== MAIN LOOP WITH DYNAMIC ENSEMBLES ========
results = []

for sel_name, sel_steps in selectors.items():
    print(f"\n=== Selector: {sel_name} ===")
    
    base_for_stack = [
        ('rf', RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=2, max_features='sqrt', random_state=GLOBAL_RANDOM_SEED)),
        ('xgb', XGBClassifier(n_estimators=200, max_depth=3, learning_rate=0.05, subsample=0.9, colsample_bytree=0.9, use_label_encoder=False, eval_metric='logloss', random_state=GLOBAL_RANDOM_SEED)),
        ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=GLOBAL_RANDOM_SEED)),
        ('svc', SVC(C=1.0, kernel='rbf', probability=True, random_state=GLOBAL_RANDOM_SEED))

        # ('rf', RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=2, max_features='sqrt', random_state=GLOBAL_RANDOM_SEED)),
        # ('xgb', XGBClassifier(n_estimators=200, max_depth=3, learning_rate=0.05, subsample=0.9, colsample_bytree=0.9, use_label_encoder=False, eval_metric='logloss', random_state=GLOBAL_RANDOM_SEED)),
        # ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=GLOBAL_RANDOM_SEED)),
        # ('svc', SVC(C=1.0, kernel='rbf', probability=True, random_state=GLOBAL_RANDOM_SEED))
    ]
    meta_lr = LogisticRegression(C=1.0, max_iter=500, solver='liblinear')
    
    # Build per-selector models dict
    models_to_run = models.copy()
    models_to_run["AdvancedStacking"] = AdvancedStackingEstimator(base_for_stack, meta_lr, sel_steps)
    
    for model_name, model in models_to_run.items():
        print(f"Processing: {sel_name} + {model_name}")
        steps = [("scaler", StandardScaler())] + sel_steps + [("smote", SMOTE(random_state=GLOBAL_RANDOM_SEED)), ("model", model)]
        pipe = ImbPipeline(steps)
        
        if model_name == "AdvancedStacking":
            pipe = model
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            y_proba = pipe.predict_proba(X_test)[:, 1]
            
            oof_aucs = {k: roc_auc_score(pipe.oof_y_true, v) for k, v in pipe.oof_results.items()}
            tuning_info = f"Meta-learner tuned. Optimal threshold: {pipe.best_threshold:.4f}"
            tuned = True
            selected_features = get_selected_features(pipe.preprocessor, X_train)

        # if model_name == "AdvancedStacking":
        #     # Use the AdvancedStackingEstimator's predict method
        #     model.fit(X_train, y_train)
        #     y_pred = model.predict(X_test)
        #     y_proba = model.predict_proba(X_test)[:, 1]
            
        #     # Get OOF results by calling cross_validated_stacking directly
        #     _, _, oof_results = cross_validated_stacking(
        #         base_for_stack, meta_lr, X_train, y_train, X_test, sel_steps
        #     )
            
        #     # Get selected features
        #     preprocessor_steps = [("scaler", StandardScaler())] + sel_steps
        #     preprocessor = ImbPipeline(preprocessor_steps)
        #     preprocessor.fit(X_train, y_train)
        #     selected_features = get_selected_features(preprocessor, X_train)
            
        #     # Calculate OOF AUCs
        #     oof_aucs = {k: roc_auc_score(y_train, v) for k, v in oof_results.items()}
            
        #     # Calculate metrics
        #     acc = accuracy_score(y_test, y_pred)
        #     prec = precision_score(y_test, y_pred, zero_division=0)
        #     rec = recall_score(y_test, y_pred, zero_division=0)
        #     f1 = f1_score(y_test, y_pred, zero_division=0)
        #     auc = roc_auc_score(y_test, y_proba)
            
        #     # Store results
        #     results.append({
        #         "Selector": sel_name,
        #         "Model": model_name,
        #         "Accuracy": acc,
        #         "Precision": prec,
        #         "Recall": rec,
        #         "F1 Score": f1,
        #         "AUC": auc,
        #         "Selected Features": selected_features,
        #         "Tuned": False,
        #         "Tuning Info": "No tuning performed",
        #         "OOF Base AUCs": oof_aucs,
        #     })
        #     continue
            
        if model_name in param_grids:
            search_cls = GridSearchCV if model_name == "Voting" else RandomizedSearchCV
            search_args = {
                "estimator": pipe,
                "param_distributions" if model_name != "Voting" else "param_grid": param_grids[model_name],
                "cv": 3, "scoring": "roc_auc", "n_jobs": -1
            }
            search = search_cls(**search_args)
            search.fit(X_train, y_train)
            best_pipe = search.best_estimator_
            y_pred = best_pipe.predict(X_test)
            y_proba = best_pipe.predict_proba(X_test)[:, 1]
            tuned = True
            tuning_info = {"best_params": search.best_params_, "best_score": search.best_score_}
            current_pipe = best_pipe
            oof_aucs = {}
        else:
            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            y_proba = pipe.predict_proba(X_test)[:, 1]
            tuned = False
            tuning_info = {}
            current_pipe = pipe
            oof_aucs = {}
        
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred, zero_division=0)
        rec = recall_score(y_test, y_pred, zero_division=0)
        f1 = f1_score(y_test, y_pred, zero_division=0)
        auc = roc_auc_score(y_test, y_proba)
        
        selected_features = X_train.columns.tolist() if sel_name=="None" else get_selected_features(current_pipe, X_train)
        
        results.append({
            "Selector": sel_name,
            "Model": model_name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1 Score": f1,
            "AUC": auc,
            "Selected Features": selected_features,
            "Tuned": tuned,
            "Tuning Info": tuning_info if tuned else "No tuning performed",
            "OOF Base AUCs": oof_aucs,
        })

# ======== SAVE & DISPLAY ========
df_results = pd.DataFrame(results)
pd.set_option("display.max_colwidth", None)
print(df_results.sort_values(by="AUC", ascending=False).to_string(index=False))
df_results.to_csv("classification_tuning_results.csv", index=False)
print("\nResults saved to CSV.")



# from sklearn.impute import KNNImputer
# from sklearn.preprocessing import StandardScaler, FunctionTransformer
# from sklearn.decomposition import PCA
# from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
# from skrebate import ReliefF
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from imblearn.over_sampling import SMOTE
# from imblearn.pipeline import Pipeline as ImbPipeline
# from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
# from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
# from scipy.stats import randint, uniform
# import seaborn as sns
# import matplotlib.pyplot as plt
# from sklearn.ensemble import VotingClassifier, StackingClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.model_selection import StratifiedKFold

# from sklearn.base import BaseEstimator, ClassifierMixin

# class AdvancedStackingEstimator(BaseEstimator, ClassifierMixin):
#     def __init__(self, base_learners=None, meta_learner=None):
#         self.base_learners = base_learners
#         self.meta_learner = meta_learner

#     def fit(self, X, y):
#         self.y_train_ = y
#         self.X_train_ = X
#         # nothing else to do for now
#         return self

#     def predict(self, X):
#         preds, _, _ = cross_validated_stacking(self.base_learners, self.meta_learner,
#                                             self.X_train_, self.y_train_, X)
#         return preds

#     def predict_proba(self, X):
#         _, probs, _ = cross_validated_stacking(self.base_learners, self.meta_learner,
#                                             self.X_train_, self.y_train_, X)
#         return np.vstack([1-probs, probs]).T

# def cross_validated_stacking(base_learners, meta_learner, X_train, y_train, X_test, preprocessor, smote, n_folds=5):
#     skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=GLOBAL_RANDOM_SEED)
#     meta_features_train = np.zeros((X_train.shape[0], len(base_learners)))
#     meta_features_test = np.zeros((X_test.shape[0], len(base_learners)))
#     oof_results = {}

#     for i, (name, model) in enumerate(base_learners):
#         fold_preds = np.zeros(X_train.shape[0])
#         test_preds = np.zeros((X_test.shape[0], n_folds))
#         for fold_idx, (train_idx, valid_idx) in enumerate(skf.split(X_train, y_train)):
#             X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[valid_idx]
#             y_tr, y_val = y_train[train_idx], y_train[valid_idx]

#             # Preprocess training data
#             X_tr_preprocessed = preprocessor.fit_transform(X_tr, y_tr)
#             X_val_preprocessed = preprocessor.transform(X_val)
            
#             # Apply SMOTE
#             X_tr_resampled, y_tr_resampled = smote.fit_resample(X_tr_preprocessed, y_tr)
            
#             model.fit(X_tr_resampled, y_tr_resampled)
#             fold_preds[valid_idx] = model.predict_proba(X_val_preprocessed)[:, 1]
            
#             # Preprocess test data
#             X_test_preprocessed = preprocessor.transform(X_test)
#             test_preds[:, fold_idx] = model.predict_proba(X_test_preprocessed)[:, 1]

#         meta_features_train[:, i] = fold_preds
#         meta_features_test[:, i] = test_preds.mean(axis=1)
#         oof_results[name] = fold_preds

#     meta_learner.fit(meta_features_train, y_train)
#     final_preds = meta_learner.predict(meta_features_test)
#     final_probs = meta_learner.predict_proba(meta_features_test)[:, 1]
#     return final_preds, final_probs, oof_results

# # def cross_validated_stacking(base_learners, meta_learner, X_train, y_train, X_test, n_folds=5):
# #     skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=GLOBAL_RANDOM_SEED)
# #     meta_features_train = np.zeros((X_train.shape[0], len(base_learners)))
# #     meta_features_test = np.zeros((X_test.shape[0], len(base_learners)))

# #     oof_results = {}

# #     for i, (name, model) in enumerate(base_learners):
# #         fold_preds = np.zeros(X_train.shape[0])
# #         test_preds = np.zeros((X_test.shape[0], n_folds))
# #         for fold_idx, (train_idx, valid_idx) in enumerate(skf.split(X_train, y_train)):
# #             X_tr, X_val = X_train[train_idx], X_train[valid_idx]
# #             y_tr, y_val = y_train[train_idx], y_train[valid_idx]
# #             model.fit(X_tr, y_tr)
# #             fold_preds[valid_idx] = model.predict_proba(X_val)[:, 1]
# #             test_preds[:, fold_idx] = model.predict_proba(X_test)[:, 1]

# #         meta_features_train[:, i] = fold_preds
# #         meta_features_test[:, i] = test_preds.mean(axis=1)
# #         oof_results[name] = fold_preds

# #     meta_learner.fit(meta_features_train, y_train)
# #     final_preds = meta_learner.predict(meta_features_test)
# #     final_probs = meta_learner.predict_proba(meta_features_test)[:, 1]
# #     return final_preds, final_probs, oof_results

# # ======== IMPUTATION ========
# dfs_imputed = []
# for source in df['source'].unique():
#     temp = df[df['source'] == source].copy()
#     numeric_cols = temp.select_dtypes(include=[np.number]).columns.drop('target')
#     imputer = KNNImputer(n_neighbors=min(5, len(temp)-1))
#     temp[numeric_cols] = imputer.fit_transform(temp[numeric_cols])
#     dfs_imputed.append(temp)

# df = pd.concat(dfs_imputed, ignore_index=True)
# df = pd.get_dummies(df, columns=['source'], prefix='src')
# df = df.fillna(df.median())

# # ======== SPLIT ========
# X = df.drop('target', axis=1)
# y = df['target'].values
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, stratify=y, random_state=GLOBAL_RANDOM_SEED
# )

# # ======== BASE LEARNERS & ENSEMBLES ========
# base_learners = [
#     ('lr', LogisticRegression(max_iter=1000)),
#     ('dt', DecisionTreeClassifier()),
#     ('rf', RandomForestClassifier()),
#     ('svm', SVC(probability=True)),
#     ('knn', KNeighborsClassifier()),
#     ('xgb', XGBClassifier(eval_metric='logloss'))
# ]

# voting_clf = VotingClassifier(estimators=base_learners, voting='soft', n_jobs=-1)
# stacking_clf = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression(),
#                                   passthrough=True, cv=5, n_jobs=-1)

# # ======== MODELS & SELECTORS ========
# models = {
#     "LogReg": LogisticRegression(max_iter=1000),
#     "DecTree": DecisionTreeClassifier(),
#     "RandForest": RandomForestClassifier(),
#     "SVM": SVC(probability=True),
#     "KNN": KNeighborsClassifier(),
#     "XGBoost": XGBClassifier(eval_metric='logloss'),
#     "Voting": voting_clf,
#     "Stacking": stacking_clf,
# }

# selectors = {
#     "None": [],
#     "Chi2": [("nonneg_shift", FunctionTransformer(lambda x: x - x.min(axis=0))),
#              ("select", SelectKBest(chi2, k=10))],
#     "MutInfo": [("select", SelectKBest(mutual_info_classif, k=9))],
#     "ReliefF": [("select", ReliefF(n_features_to_select=9))],
#     "PCA": [("reduce", PCA(n_components=10))]
# }

# # ======== HYPERPARAMETER GRIDS ========
# param_grids = {
#     "LogReg": {"model__C": uniform(0.1, 10), "model__penalty": ['l2', None],
#                "model__solver": ['newton-cg', 'lbfgs', 'sag']},
#     "DecTree": {"model__max_depth": [None, 5, 10, 15, 20, 25], "model__min_samples_split": randint(2, 20),
#                 "model__min_samples_leaf": randint(1, 10), "model__max_features": ['sqrt', 'log2', None]},
#     "RandForest": {"model__n_estimators": [100, 200, 300], "model__max_depth": [None, 10, 20, 30],
#                    "model__min_samples_split": [2, 5, 10], "model__min_samples_leaf": [1, 2, 4],
#                    "model__max_features": ['sqrt', 'log2']},
#     "SVM": {"model__C": uniform(0.1, 10), "model__kernel": ['linear', 'rbf', 'poly'], "model__gamma": ['scale']},
#     "KNN": {"model__n_neighbors": randint(3, 15), "model__weights": ['uniform', 'distance'], "model__p": [1, 2]},
#     "XGBoost": {"model__n_estimators": [100, 200, 300], "model__max_depth": [3, 6, 9],
#                 "model__learning_rate": [0.01, 0.05, 0.1], "model__subsample": [0.8, 0.9, 1.0],
#                 "model__colsample_bytree": [0.8, 0.9, 1.0]},
#     "Voting": {"model__weights": [[1, 1, 1, 1, 1, 1], [1, 1, 2, 1, 1, 2], [1, 1, 3, 1, 1, 3]]}
# }

# # ======== FEATURE EXTRACTION ========
# def get_selected_features(pipe, X_train):
#     try:
#         if "select" in pipe.named_steps:
#             sel = pipe.named_steps["select"]
#             if hasattr(sel, "get_support"):
#                 return X_train.columns[sel.get_support()].tolist()
#             if hasattr(sel, "top_features_"):
#                 return [X_train.columns[i] for i in sel.top_features_]
#         if "reduce" in pipe.named_steps:
#             pc = pipe.named_steps["reduce"]
#             n = getattr(pc, "n_components_", getattr(pc, "n_components", None))
#             if n: return [f"PC{i+1}" for i in range(n)]
#     except Exception as e:
#         return [f"[Error: {e}]"]
#     return ["[No selector]"]

# # ======== MAIN LOOP WITH DYNAMIC ENSEMBLES ========
# results = []

# for sel_name, sel_steps in selectors.items():
#     print(f"\n=== Selector: {sel_name} ===")
    
#     # # Build selector-aware WeightedVoting
#     # weighted_voting_clf, computed_weights = build_cv_weighted_voting_for_selector(
#     #     base_learners=base_learners, selector_steps=sel_steps,
#     #     X=X_train, y=y_train, cv=3, scoring='roc_auc'
#     # )
#     # print("Computed selector-aware weights:", computed_weights)
    

#     # skip pipeline fit, call function directly
#     base_for_stack = [
#         ('rf', RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=2, max_features='sqrt', random_state=GLOBAL_RANDOM_SEED)),
#         ('xgb', XGBClassifier(n_estimators=200, max_depth=3, learning_rate=0.05, subsample=0.9, colsample_bytree=0.9, use_label_encoder=False, eval_metric='logloss', random_state=GLOBAL_RANDOM_SEED)),
#         ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=GLOBAL_RANDOM_SEED)),
#         ('svc', SVC(C=1.0, kernel='rbf', probability=True, random_state=GLOBAL_RANDOM_SEED))
#     ]
#     meta_lr = LogisticRegression(C=1.0, max_iter=500, solver='liblinear')
#     # Build per-selector models dict
#     models_to_run = models.copy()
#     # models_to_run["WeightedVoting"] = weighted_voting_clf
#     # models_to_run["TieredStacking"] = TieredStackingClassifier(
#     #     groups={
#     #         "linear": [('lr', LogisticRegression(max_iter=1000)), ('svm_lin', SVC(kernel='linear', probability=True))],
#     #         "tree": [('dt', DecisionTreeClassifier()),
#     #                  ('rf', RandomForestClassifier(n_estimators=200, random_state=GLOBAL_RANDOM_SEED)),
#     #                  ('xgb', XGBClassifier(eval_metric='logloss'))],
#     #         "distance": [('knn', KNeighborsClassifier())]
#     #     },
#     #     meta_estimators={
#     #         "linear": LogisticRegression(max_iter=1000),
#     #         "tree": LogisticRegression(max_iter=1000),
#     #         "distance": LogisticRegression(max_iter=1000)
#     #     },
#     #     final_estimator=LogisticRegression(max_iter=1000),
#     #     cv=5, random_state=GLOBAL_RANDOM_SEED
#     # )
#     models_to_run["AdvancedStacking"] = AdvancedStackingEstimator(base_for_stack, meta_lr)
#     # models_to_run["HybridStacking"] = build_hybrid_stacking(random_state=GLOBAL_RANDOM_SEED)
    
#     for model_name, model in models_to_run.items():
#         print(f"Processing: {sel_name} + {model_name}")
#         steps = [("scaler", StandardScaler())] + sel_steps + [("smote", SMOTE(random_state=GLOBAL_RANDOM_SEED)), ("model", model)]
#         pipe = ImbPipeline(steps)
        
#         if model_name == "AdvancedStacking":
#             # Create preprocessor without SMOTE
#             preprocessor_steps = [("scaler", StandardScaler())] + sel_steps
#             preprocessor = ImbPipeline(preprocessor_steps)
#             smote = SMOTE(random_state=GLOBAL_RANDOM_SEED)
            
#             y_pred, y_proba, oof_results = cross_validated_stacking(
#                 base_for_stack, meta_lr, X_train, y_train, X_test, preprocessor, smote
#             )
            
#             # Fit preprocessor to get feature names
#             preprocessor.fit(X_train, y_train)
#             selected_features = get_selected_features(preprocessor, X_train)
#             oof_aucs = {k: roc_auc_score(y_train, v) for k, v in oof_results.items()}
            
#             # Store results
#             results.append({
#                 "Selector": sel_name,
#                 "Model": model_name,
#                 # ... [other metrics] ...
#                 "OOF Base AUCs": oof_aucs,
#             })
#             continue
#         # if model_name == "AdvancedStacking":
#         #     y_pred, y_proba, oof_results = cross_validated_stacking(
#         #         base_for_stack, meta_lr, X_train.values, y_train, X_test.values
#         #     )
#         #     tuned = False
#         #     tuning_info = "No tuning performed"
#         #     selected_features = X_train.columns.tolist() if sel_name=="None" else get_selected_features(pipe, X_train)
#         #     oof_aucs = {k: roc_auc_score(y_train, v) for k, v in oof_results.items()}
#         if model_name in param_grids:
#             search_cls = GridSearchCV if model_name == "Voting" else RandomizedSearchCV
#             search_args = {
#                 "estimator": pipe,
#                 "param_distributions" if model_name != "Voting" else "param_grid": param_grids[model_name],
#                 "cv": 3, "scoring": "roc_auc", "n_jobs": -1
#             }
#             search = search_cls(**search_args)
#             search.fit(X_train, y_train)
#             best_pipe = search.best_estimator_
#             y_pred = best_pipe.predict(X_test)
#             y_proba = best_pipe.predict_proba(X_test)[:, 1]
#             tuned = True
#             tuning_info = {"best_params": search.best_params_, "best_score": search.best_score_}
#             current_pipe = best_pipe
#             oof_aucs = {}
#         else:
#             pipe.fit(X_train, y_train)
#             y_pred = pipe.predict(X_test)
#             y_proba = pipe.predict_proba(X_test)[:, 1]
#             tuned = False
#             tuning_info = {}
#             current_pipe = pipe
#             oof_aucs = {}
        
#         acc = accuracy_score(y_test, y_pred)
#         prec = precision_score(y_test, y_pred, zero_division=0)
#         rec = recall_score(y_test, y_pred, zero_division=0)
#         f1 = f1_score(y_test, y_pred, zero_division=0)
#         auc = roc_auc_score(y_test, y_proba)
        
#         selected_features = X_train.columns.tolist() if sel_name=="None" else get_selected_features(current_pipe, X_train)
        
#         results.append({
#             "Selector": sel_name,
#             "Model": model_name,
#             "Accuracy": acc,
#             "Precision": prec,
#             "Recall": rec,
#             "F1 Score": f1,
#             "AUC": auc,
#             "Selected Features": selected_features,
#             "Tuned": tuned,
#             "Tuning Info": tuning_info if tuned else "No tuning performed",
#             "OOF Base AUCs": oof_aucs,
#         })

# # ======== SAVE & DISPLAY ========
# df_results = pd.DataFrame(results)
# pd.set_option("display.max_colwidth", None)
# print(df_results.sort_values(by="AUC", ascending=False).to_string(index=False))
# df_results.to_csv("classification_tuning_results.csv", index=False)
# print("\nResults saved to CSV.")
# Out:
# === Selector: None ===
# Processing: None + LogReg
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Processing: None + DecTree
# Processing: None + RandForest
# Processing: None + SVM
# Processing: None + KNN
# Processing: None + XGBoost
# Processing: None + Voting
# Processing: None + Stacking
# Processing: None + AdvancedStacking
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:23] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:23] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Selector: Chi2 ===
# Processing: Chi2 + LogReg
# Processing: Chi2 + DecTree
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Processing: Chi2 + RandForest
# Processing: Chi2 + SVM
# Processing: Chi2 + KNN
# Processing: Chi2 + XGBoost
# Processing: Chi2 + Voting
# Processing: Chi2 + Stacking
# Processing: Chi2 + AdvancedStacking
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:45] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:19:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Selector: MutInfo ===
# Processing: MutInfo + LogReg
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Processing: MutInfo + DecTree
# Processing: MutInfo + RandForest
# Processing: MutInfo + SVM
# Processing: MutInfo + KNN
# Processing: MutInfo + XGBoost
# Processing: MutInfo + Voting
# Processing: MutInfo + Stacking
# Processing: MutInfo + AdvancedStacking
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:16] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:20:16] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Selector: ReliefF ===
# Processing: ReliefF + LogReg
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Processing: ReliefF + DecTree
# Processing: ReliefF + RandForest
# Processing: ReliefF + SVM
# Processing: ReliefF + KNN
# Processing: ReliefF + XGBoost
# Processing: ReliefF + Voting
# Processing: ReliefF + Stacking
# Processing: ReliefF + AdvancedStacking
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:21:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:21:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:21:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:21:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:21:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:02] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:02] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:02] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Selector: PCA ===
# Processing: PCA + LogReg
# Processing: PCA + DecTree
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/arash/.pyenv/versions/3.12.8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Processing: PCA + RandForest
# Processing: PCA + SVM
# Processing: PCA + KNN
# Processing: PCA + XGBoost
# Processing: PCA + Voting
# Processing: PCA + Stacking
# Processing: PCA + AdvancedStacking
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:17] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:17] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:18] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:18] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:19] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/arash/.pyenv/versions/tf312/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [13:22:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Selector            Model  Accuracy  Precision   Recall  F1 Score      AUC                                                                                                                             Selected Features  Tuned                                                                                                                                                                                           Tuning Info OOF Base AUCs
#     None AdvancedStacking  0.858696   0.845455 0.911765  0.877358 0.937111 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]  False                                                                                                                                                                                   No tuning performed            {}
#     None       RandForest  0.858696   0.865385 0.882353  0.873786 0.935916 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True {'best_params': {'model__n_estimators': 100, 'model__min_samples_split': 2, 'model__min_samples_leaf': 4, 'model__max_features': 'log2', 'model__max_depth': None}, 'best_score': 0.8884368994253866}            {}
#  ReliefF          XGBoost  0.858696   0.887755 0.852941  0.870000 0.934182 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True         {'best_params': {'model__subsample': 0.9, 'model__n_estimators': 100, 'model__max_depth': 3, 'model__learning_rate': 0.05, 'model__colsample_bytree': 1.0}, 'best_score': 0.8822140439594118}            {}
#  ReliefF       RandForest  0.869565   0.882353 0.882353  0.882353 0.934003 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True   {'best_params': {'model__n_estimators': 200, 'model__min_samples_split': 5, 'model__min_samples_leaf': 4, 'model__max_features': 'log2', 'model__max_depth': 20}, 'best_score': 0.8785944441718861}            {}
#     Chi2       RandForest  0.836957   0.875000 0.823529  0.848485 0.931552                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True   {'best_params': {'model__n_estimators': 200, 'model__min_samples_split': 2, 'model__min_samples_leaf': 2, 'model__max_features': 'sqrt', 'model__max_depth': 10}, 'best_score': 0.8705667349879439}            {}
#     None          XGBoost  0.869565   0.882353 0.882353  0.882353 0.930057 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True         {'best_params': {'model__subsample': 0.9, 'model__n_estimators': 200, 'model__max_depth': 3, 'model__learning_rate': 0.05, 'model__colsample_bytree': 0.8}, 'best_score': 0.8877772538601825}            {}
#     Chi2 AdvancedStacking  0.847826   0.824561 0.921569  0.870370 0.929878                                                                  [[Error: 'AdvancedStackingEstimator' object has no attribute 'named_steps']]  False                                                                                                                                                                                   No tuning performed            {}
#     Chi2          XGBoost  0.847826   0.870000 0.852941  0.861386 0.927965                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True         {'best_params': {'model__subsample': 0.8, 'model__n_estimators': 100, 'model__max_depth': 3, 'model__learning_rate': 0.05, 'model__colsample_bytree': 0.9}, 'best_score': 0.8778267754295367}            {}
#  MutInfo       RandForest  0.831522   0.838095 0.862745  0.850242 0.925753                                                                                     [age, cp, chol, thalach, exang, oldpeak, slope, ca, thal]   True  {'best_params': {'model__n_estimators': 300, 'model__min_samples_split': 10, 'model__min_samples_leaf': 1, 'model__max_features': 'log2', 'model__max_depth': 30}, 'best_score': 0.8807397958720139}            {}
#  ReliefF AdvancedStacking  0.858696   0.858491 0.892157  0.875000 0.925036                                                                  [[Error: 'AdvancedStackingEstimator' object has no attribute 'named_steps']]  False                                                                                                                                                                                   No tuning performed            {}
#      PCA           Voting  0.869565   0.875000 0.892157  0.883495 0.923362                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True                                                                                                             {'best_params': {'model__weights': [1, 1, 1, 1, 1, 1]}, 'best_score': 0.8930943436281625}            {}
#      PCA AdvancedStacking  0.847826   0.813559 0.941176  0.872727 0.922406                                                                  [[Error: 'AdvancedStackingEstimator' object has no attribute 'named_steps']]  False                                                                                                                                                                                   No tuning performed            {}
#      PCA         Stacking  0.842391   0.861386 0.852941  0.857143 0.922166                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]  False                                                                                                                                                                                   No tuning performed            {}
#     None           Voting  0.842391   0.861386 0.852941  0.857143 0.921449 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True                                                                                                             {'best_params': {'model__weights': [1, 1, 1, 1, 1, 1]}, 'best_score': 0.8885666174850381}            {}
#      PCA          XGBoost  0.858696   0.887755 0.852941  0.870000 0.920851                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True         {'best_params': {'model__subsample': 0.9, 'model__n_estimators': 100, 'model__max_depth': 3, 'model__learning_rate': 0.05, 'model__colsample_bytree': 1.0}, 'best_score': 0.8918859004386976}            {}
#  MutInfo AdvancedStacking  0.847826   0.849057 0.882353  0.865385 0.920134                                                                  [[Error: 'AdvancedStackingEstimator' object has no attribute 'named_steps']]  False                                                                                                                                                                                   No tuning performed            {}
#     Chi2         Stacking  0.858696   0.872549 0.872549  0.872549 0.918400                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]  False                                                                                                                                                                                   No tuning performed            {}
#      PCA       RandForest  0.864130   0.881188 0.872549  0.876847 0.917504                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True   {'best_params': {'model__n_estimators': 300, 'model__min_samples_split': 2, 'model__min_samples_leaf': 4, 'model__max_features': 'sqrt', 'model__max_depth': 20}, 'best_score': 0.8909277808364875}            {}
#  ReliefF         Stacking  0.869565   0.897959 0.862745  0.880000 0.917145 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]  False                                                                                                                                                                                   No tuning performed            {}
#  MutInfo          XGBoost  0.826087   0.836538 0.852941  0.844660 0.917025                                                                       [cp, chol, thalach, exang, oldpeak, slope, ca, src_switzerland, src_va]   True         {'best_params': {'model__subsample': 0.8, 'model__n_estimators': 200, 'model__max_depth': 3, 'model__learning_rate': 0.05, 'model__colsample_bytree': 0.8}, 'best_score': 0.8758923497734435}            {}
#     None              SVM  0.847826   0.870000 0.852941  0.861386 0.916846 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True                                                              {'best_params': {'model__C': 0.15184862773986776, 'model__gamma': 'scale', 'model__kernel': 'linear'}, 'best_score': 0.8997058853813665}            {}
#     None         Stacking  0.836957   0.846154 0.862745  0.854369 0.915949 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]  False                                                                                                                                                                                   No tuning performed            {}
#      PCA              KNN  0.853261   0.886598 0.843137  0.864322 0.915890                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True                                                                            {'best_params': {'model__n_neighbors': 14, 'model__p': 1, 'model__weights': 'distance'}, 'best_score': 0.8887761958797666}            {}
#      PCA              SVM  0.836957   0.860000 0.843137  0.851485 0.915591                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True                                                               {'best_params': {'model__C': 0.5867870868164847, 'model__gamma': 'scale', 'model__kernel': 'linear'}, 'best_score': 0.8971022738629323}            {}
#     Chi2           Voting  0.831522   0.865979 0.823529  0.844221 0.914574                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True                                                                                                             {'best_params': {'model__weights': [1, 1, 1, 1, 1, 1]}, 'best_score': 0.8717527027182541}            {}
#  ReliefF           Voting  0.858696   0.887755 0.852941  0.870000 0.914156 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True                                                                                                             {'best_params': {'model__weights': [1, 1, 1, 1, 1, 1]}, 'best_score': 0.8711306232560054}            {}
#  ReliefF           LogReg  0.847826   0.885417 0.833333  0.858586 0.912721 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True                                                                  {'best_params': {'model__C': 6.131341611036362, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}, 'best_score': 0.8886402733335634}            {}
#  ReliefF          DecTree  0.826087   0.830189 0.862745  0.846154 0.911645 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True                               {'best_params': {'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 7, 'model__min_samples_split': 5}, 'best_score': 0.8445235514587016}            {}
#  MutInfo              SVM  0.826087   0.864583 0.813725  0.838384 0.911406                                                                         [cp, chol, thalach, exang, oldpeak, slope, ca, thal, src_switzerland]   True                                                                {'best_params': {'model__C': 5.411679344262646, 'model__gamma': 'scale', 'model__kernel': 'linear'}, 'best_score': 0.8941168551255797}            {}
#      PCA           LogReg  0.826087   0.864583 0.813725  0.838384 0.910689                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True                                                                   {'best_params': {'model__C': 0.7818636823657953, 'model__penalty': 'l2', 'model__solver': 'sag'}, 'best_score': 0.8964519089073865}            {}
#  ReliefF              SVM  0.836957   0.875000 0.823529  0.848485 0.909613 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True                                                                 {'best_params': {'model__C': 8.03397582153967, 'model__gamma': 'scale', 'model__kernel': 'linear'}, 'best_score': 0.8853998127221728}            {}
#     None              KNN  0.831522   0.865979 0.823529  0.844221 0.909553 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True                                                                             {'best_params': {'model__n_neighbors': 14, 'model__p': 1, 'model__weights': 'uniform'}, 'best_score': 0.8892571560178144}            {}
#  MutInfo              KNN  0.836957   0.860000 0.843137  0.851485 0.908596                                                                                     [sex, cp, chol, thalach, exang, oldpeak, slope, ca, thal]   True                                                                            {'best_params': {'model__n_neighbors': 11, 'model__p': 2, 'model__weights': 'distance'}, 'best_score': 0.8773616978685337}            {}
#     Chi2              SVM  0.831522   0.865979 0.823529  0.844221 0.908477                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True                                                                {'best_params': {'model__C': 9.421182824836123, 'model__gamma': 'scale', 'model__kernel': 'linear'}, 'best_score': 0.8869811307898194}            {}
#     Chi2           LogReg  0.836957   0.875000 0.823529  0.848485 0.907879                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True                                                                 {'best_params': {'model__C': 1.7621543190925293, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}, 'best_score': 0.8865941949324752}            {}
#     None           LogReg  0.831522   0.873684 0.813725  0.842640 0.907819 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True                                                            {'best_params': {'model__C': 0.17066305219717406, 'model__penalty': 'l2', 'model__solver': 'newton-cg'}, 'best_score': 0.9002196925784801}            {}
#  MutInfo           Voting  0.820652   0.841584 0.833333  0.837438 0.907461                                                                                     [age, cp, chol, thalach, exang, oldpeak, slope, ca, thal]   True                                                                                                             {'best_params': {'model__weights': [1, 1, 1, 1, 1, 1]}, 'best_score': 0.8815198713161476}            {}
#  MutInfo         Stacking  0.826087   0.857143 0.823529  0.840000 0.906982                                                                                     [age, cp, chol, thalach, exang, oldpeak, slope, ca, thal]  False                                                                                                                                                                                   No tuning performed            {}
#  MutInfo           LogReg  0.831522   0.873684 0.813725  0.842640 0.904352                                                                                     [age, cp, chol, thalach, exang, oldpeak, slope, ca, thal]   True                                                                  {'best_params': {'model__C': 9.720987857641177, 'model__penalty': 'l2', 'model__solver': 'lbfgs'}, 'best_score': 0.8945364888920384}            {}
#     Chi2              KNN  0.815217   0.854167 0.803922  0.828283 0.897716                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True                                                                             {'best_params': {'model__n_neighbors': 12, 'model__p': 2, 'model__weights': 'uniform'}, 'best_score': 0.8787898502928185}            {}
#  ReliefF              KNN  0.804348   0.836735 0.803922  0.820000 0.897119 [exang, cp, ca, thal, oldpeak, src_hungarian, chol, src_cleveland, slope, src_switzerland, src_va, thalach, age, sex, restecg, trestbps, fbs]   True                                                                             {'best_params': {'model__n_neighbors': 11, 'model__p': 2, 'model__weights': 'uniform'}, 'best_score': 0.8852067612019942}            {}
#     None          DecTree  0.798913   0.865169 0.754902  0.806283 0.882174 [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, src_cleveland, src_hungarian, src_switzerland, src_va]   True                               {'best_params': {'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10}, 'best_score': 0.8349271656118663}            {}
#  MutInfo          DecTree  0.766304   0.770642 0.823529  0.796209 0.858740                                                                                     [age, cp, chol, thalach, exang, oldpeak, slope, ca, thal]   True                               {'best_params': {'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 17}, 'best_score': 0.8386451612121698}            {}
#     Chi2          DecTree  0.793478   0.813725 0.813725  0.813725 0.850729                                                            [sex, cp, thalach, exang, slope, ca, thal, src_hungarian, src_switzerland, src_va]   True                            {'best_params': {'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 8, 'model__min_samples_split': 19}, 'best_score': 0.8400313775156373}            {}
#      PCA          DecTree  0.777174   0.835165 0.745098  0.787565 0.839431                                                                                           [PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10]   True                              {'best_params': {'model__max_depth': 25, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 6, 'model__min_samples_split': 14}, 'best_score': 0.8378933614189505}            {}
#
# Results saved to CSV.

# %%
# ========== HITMAPS ==========
metrics = ["Accuracy", "Precision", "Recall", "F1 Score", "AUC"]
cmap_dict = {
    "Accuracy": "magma",
    "Precision": "coolwarm",
    "Recall": "cubehelix",
    "F1 Score": "YlGnBu",
    "AUC": "viridis"
}

plt.figure(figsize=(15, 18))
sns.set_theme(style="whitegrid")

for i, metric in enumerate(metrics, 1):
    plt.subplot(3, 2, i)
    metric_matrix = df_results.pivot(index="Selector", columns="Model", values=metric)
    sns.heatmap(metric_matrix, annot=True, fmt=".3f", cmap=cmap_dict[metric], cbar_kws={'label': metric})
    plt.title(f"{metric} by Selector and Model")
    plt.xlabel("Model")
    plt.ylabel("Feature Selector")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics to visualize
metrics = ["Accuracy", "Precision", "Recall", "F1 Score", "AUC"]

# List of unique models and selectors for ordering
models = df_results['Model'].unique()
selectors = df_results['Selector'].unique()

plt.figure(figsize=(18, 20))
for i, metric in enumerate(metrics, 1):
    plt.subplot(3, 2, i)
    
    for sel in selectors:
        subset = df_results[df_results['Selector'] == sel]
        # Ensure consistent order by model
        subset = subset.set_index('Model').reindex(models)
        plt.plot(models, subset[metric], marker='o', label=sel)
    
    plt.title(f"{metric} by Model and Selector")
    plt.xlabel("Model")
    plt.ylabel(metric)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend(title="Selector")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics to visualize
metrics = ["Accuracy", "AUC"]

# List of unique models and selectors for ordering
models = df_results['Model'].unique()
selectors = df_results['Selector'].unique()

plt.figure(figsize=(18, 20))
for i, metric in enumerate(metrics, 1):
    plt.subplot(3, 2, i)
    
    for sel in selectors:
        subset = df_results[df_results['Selector'] == sel]
        # Ensure consistent order by model
        subset = subset.set_index('Model').reindex(models)
        plt.plot(models, subset[metric], marker='o', label=sel)
    
    plt.title(f"{metric} by Model and Selector")
    plt.xlabel("Model")
    plt.ylabel(metric)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend(title="Selector")

plt.tight_layout()
plt.show()
